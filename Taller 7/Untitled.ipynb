# %% [markdown]
# # Taller 7

# %% [markdown]
# # Punto 1

# %%
import sys
import numpy as np
import pylab as pl
import random as rnd
import Queue
from matplotlib import pyplot as plt
from matplotlib.path import Path
from matplotlib.patches import PathPatch
from __future__ import print_function
from mpl_toolkits.mplot3d import Axes3D

# %% [raw]
# Como variales se cuenta con :
# x1 = Corn
# x2 = Soybeanmeal
# La funcion minima que se desea:
# Z(min) = 0.3x1 + 0.9x2
# Restricciones:
# x1 + x2 >= 800
# 0.21x1 - 0.3x2 <= 0
# 0.03x1 - 0.01 x2 <= 0
# x2 >= 0

# %%
fig, ax = plt.subplots(figsize=(8, 8))
x1 = np.linspace(0, 1000)

plt.plot(x1, 800 - x1, lw=3, label=r'$x_1+x_2\geq 800$')
plt.fill_between(x1, 1000, 800 - x1, alpha=0.1)

plt.plot(x1, 0.21*x1/0.3, lw=3, label=r'$0.21x_1-0.3x_2\leq 0$')
plt.fill_between(x1, 1000,0.21*x1/0.3, alpha=0.1)

plt.plot(x1, 0.03*x1/0.01, lw=3, label=r'$0.03x_1-0.01x_2\geq 0$')
plt.fill_betweenx(x1,0.01*x1/0.03,1000, alpha=0.1)

plt.plot(np.zeros_like(x1), x1, lw=3, label=r'$x_2\geq 0$')
plt.plot(x1, np.zeros_like(x1), lw=3, label=r'$x_1\geq 0$')

plt.xlabel(r'$x_1$', fontsize=16)
plt.ylabel(r'$x_2$', fontsize=16)
plt.xlim(-0.1, 1000)
plt.ylim(-0.1, 1000)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # Punto 2

# %% [raw]
# Como variales se cuenta con :
# x1 = Soldering
# x2 = Assembling
# La funcion maxima que se desea:
# Z(min) = 30x1 + 20x2
# Restricciones:
# x1 + x2 >= 800
# 2x1 + x2 <= 1000
# x1 >= 0
# x2 >= 0

# %%
fig, ax = plt.subplots(figsize=(8, 8))
x1 = np.linspace(0, 1000)

plt.plot(x1, 1000 - 2*x1, lw=3, label=r'$2x_1+x_2\leq 1000$')
plt.fill_between(x1,0, 1000 - 2*x1, alpha=0.1)

plt.plot(x1, 800-x1, lw=3, label=r'$x_1+x_2\leq 800$')
plt.fill_between(x1,0,800-x1, alpha=0.1)

plt.plot(np.ones_like(x1)*350,x1, lw=3, label=r'$x_1\leq 350$')
plt.fill_betweenx(x1, 0,350, alpha=0.1)

plt.plot(np.zeros_like(x1), x1, lw=3, label=r'$x_2\geq 0$')
plt.plot(x1, np.zeros_like(x1), lw=3, label=r'$x_1\geq 0$')

plt.xlabel(r'$x_1$', fontsize=16)
plt.ylabel(r'$x_2$', fontsize=16)
plt.xlim(-0.1, 1000)
plt.ylim(-0.1, 1000)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # Punto 3

# %% [raw]
# Con el fin de hallar la funcion minima requerida se tienen como restricciones iniciales:
# 1. x1 + x2 <= 4
# 2. x1 + x2 <= 12
# 3. x1 + x2 <= 1
# Y como escuación inicial:
#  z(Max) = x1 + x2
# por lo tanto se obtienen:
# 1. 1y1 + 4y2 - y3
# 2. 2yi + 2y2 + y3
# 3. 0

# %%
x = np.outer(np.linspace(-1, 2, 50), np.ones(50))
y = x.copy().T
z = x.copy().T
z1 = x+4*y
z2 = -2*x-2*y
z3 = 0
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$x_3$')
ax.plot_surface(x, y, z1, color='blue', alpha=0.7)
ax.plot_surface(x, y, z2, color='pink', alpha=0.7)
plt.show()
